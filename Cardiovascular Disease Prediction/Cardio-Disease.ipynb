# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')
df.head(10)
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
# 5     148462   24       1          1        173                0
# 6     168686   79       1          2        130              240
# 7     170498   52       1          0        127              345
# 8     188225   62       1          0        121              357
# 9     192523   61       0          0        190              181
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
# 5                  0                0           161              0      4.7
# 6                  0                2           157              0      2.5
# 7                  0                0           192              1      4.9
# 8                  0                1           138              0      2.8
# 9                  0                1           150              0      2.9
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# 2      1                 0       0
# 3      2                 2       1
# 4      3                 2       1
# 5      3                 2       1
# 6      2                 1       1
# 7      1                 0       0
# 8      0                 0       0
# 9      2                 0       1

# %%
df.rename(columns={'patientid':'ID'},inplace=True)
gender = {0: 'Female', 1: 'Male'}
df['gender'] = df['gender'].replace(gender)
df
# Out:
#           ID  age gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53   Male          2        171                0
# 1     119250   40   Male          0         94              229
# 2     119372   49   Male          2        133              142
# 3     132514   43   Male          0        138              295
# 4     146211   31   Male          1        199                0
# ..       ...  ...    ...        ...        ...              ...
# 995  9949544   48   Male          2        139              349
# 996  9953423   47   Male          3        143              258
# 997  9965859   69   Male          0        156              434
# 998  9988507   45   Male          1        186              417
# 999  9990855   25   Male          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# 1                    0                1           115              0      3.7
# 2                    0                0           202              1      5.0
# 3                    1                1           153              0      3.2
# 4                    0                2           136              0      5.3
# ..                 ...              ...           ...            ...      ...
# 995                  0                2           183              1      5.6
# 996                  1                1            98              1      5.7
# 997                  1                0           196              0      1.4
# 998                  0                1           117              1      5.9
# 999                  0                0           143              1      4.7
#
#      slope  noofmajorvessels  target
# 0        3                 3       1
# 1        1                 1       0
# 2        1                 0       0
# 3        2                 2       1
# 4        3                 2       1
# ..     ...               ...     ...
# 995      2                 2       1
# 996      1                 0       0
# 997      3                 1       1
# 998      3                 2       1
# 999      0                 0       0
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Check for null values and duplicated

# %%
df.isna().sum()
# Out:
# ID                   0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   age                1000 non-null   int64
#  2   gender             1000 non-null   object
#  3   chestpain          1000 non-null   int64
#  4   restingBP          1000 non-null   int64
#  5   serumcholestrol    1000 non-null   int64
#  6   fastingbloodsugar  1000 non-null   int64
#  7   restingrelectro    1000 non-null   int64
#  8   maxheartrate       1000 non-null   int64
#  9   exerciseangia      1000 non-null   int64
#  10  oldpeak            1000 non-null   float64
#  11  slope              1000 non-null   int64
#  12  noofmajorvessels   1000 non-null   int64
#  13  target             1000 non-null   int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 109.5+ KB

# %%
df.describe(include='all')
# Out:
#                   ID         age gender    chestpain    restingBP  \
# count   1.000000e+03  1000.00000   1000  1000.000000  1000.000000
# unique           NaN         NaN      2          NaN          NaN
# top              NaN         NaN   Male          NaN          NaN
# freq             NaN         NaN    765          NaN          NaN
# mean    5.048704e+06    49.24200    NaN     0.980000   151.747000
# std     2.895905e+06    17.86473    NaN     0.953157    29.965228
# min     1.033680e+05    20.00000    NaN     0.000000    94.000000
# 25%     2.536440e+06    34.00000    NaN     0.000000   129.000000
# 50%     4.952508e+06    49.00000    NaN     1.000000   147.000000
# 75%     7.681877e+06    64.25000    NaN     2.000000   181.000000
# max     9.990855e+06    80.00000    NaN     3.000000   200.000000
#
#         serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count       1000.000000        1000.000000      1000.000000   1000.000000
# unique              NaN                NaN              NaN           NaN
# top                 NaN                NaN              NaN           NaN
# freq                NaN                NaN              NaN           NaN
# mean         311.447000           0.296000         0.748000    145.477000
# std          132.443801           0.456719         0.770123     34.190268
# min            0.000000           0.000000         0.000000     71.000000
# 25%          235.750000           0.000000         0.000000    119.750000
# 50%          318.000000           0.000000         1.000000    146.000000
# 75%          404.250000           1.000000         1.000000    175.000000
# max          602.000000           1.000000         2.000000    202.000000
#
#         exerciseangia      oldpeak        slope  noofmajorvessels       target
# count     1000.000000  1000.000000  1000.000000       1000.000000  1000.000000
# unique            NaN          NaN          NaN               NaN          NaN
# top               NaN          NaN          NaN               NaN          NaN
# freq              NaN          NaN          NaN               NaN          NaN
# mean         0.498000     2.707700     1.540000          1.222000     0.580000
# std          0.500246     1.720753     1.003697          0.977585     0.493805
# min          0.000000     0.000000     0.000000          0.000000     0.000000
# 25%          0.000000     1.300000     1.000000          0.000000     0.000000
# 50%          0.000000     2.400000     2.000000          1.000000     1.000000
# 75%          1.000000     4.100000     2.000000          2.000000     1.000000
# max          1.000000     6.200000     3.000000          3.000000     1.000000

# %%
print(df['chestpain'].unique())
print(df['chestpain'].value_counts())
chest = {
    0: "typical angina",
    1: "atypical angina",
    2: "non-anginal pain",
    3: "asymptomatic"
}
# Out:
# [2 0 1 3]
# 0    420
# 2    312
# 1    224
# 3     44
# Name: chestpain, dtype: int64

# %%
def PiePlot(column,shadow=None):
    '''
    Parameters:
    -column(Optional): column in df to be visualized
    -shadow(Optional): Apply shadow effect on pie chart 
    
    '''
    plt.figure(figsize=(12,6))
    plt.pie(df[column].value_counts(), labels = df[column].value_counts().index, shadow = True, autopct = "%1.1f%%")
    plt.title(f'Pie Chart of {column}')
    plt.show()

# %% [markdown]
# # Visualization for Chestpain

# %%
PiePlot('chestpain')
for i in np.sort(df['chestpain'].unique()):
    print(f'Type {i} is {chest[i]}')
# Out:
# Type 0 is typical angina
# Type 1 is atypical angina
# Type 2 is non-anginal pain
# Type 3 is asymptomatic

# %%
def countplot(data, hue=None, column_x=None, column_y=None, order=None, order_hue=None, saturation=1.0, label_dict=None):
    """
    Parameters:
    - data: DataFrame
        The input DataFrame.
    - hue: str, optional
        Variable in data to map plot aspects to different colors.
    - column_x: str, optional
        Categorical variable on the x-axis.
    - column_y: str, optional
        Categorical variable on the y-axis.
    - order: list, optional
        Order to plot the categorical levels in the x-axis or y-axis.
    - order_hue: list, optional
        Order to plot the categorical levels in the hue variable.
    - saturation: float, optional
        Proportion to desaturate the plot.
    - label_dict: dict, optional
        Dictionary to map values to custom labels.

    """
    plt.figure(figsize=(10, 6))  
    
    if column_x and column_y:
        raise ValueError("Specify either column_x or column_y")
    elif column_x:
        plt.title(f'Countplot graph for {column_x} ')
        sns.countplot(x=column_x, hue=hue, data=data, order=order, hue_order=order_hue, saturation=saturation)
        if order is not None and label_dict is not None:
            plt.xticks(ticks=range(len(order)), labels=[f' {i}: {label_dict[val]}' for i, val in enumerate(order)])
    elif column_y:
        plt.title(f'Countplot graph for {column_y} ')
        sns.countplot(y=column_y, hue=hue, data=data, order=order, hue_order=order_hue, saturation=saturation)
        if order is not None and label_dict is not None:
            plt.yticks(ticks=range(len(order)), labels=[f' {i}: {label_dict[val]}' for i, val in enumerate(order)])
    else:
        sns.countplot(x=None, y=None, hue=hue, data=data, order=order, hue_order=order_hue, saturation=saturation)

    plt.show()

# %%
countplot(data=df, column_y='chestpain', order=sorted(df['chestpain'].unique()), saturation=0.8, label_dict=chest)

# %%
countplot(data=df,column_x='gender')

# %% [markdown]
# # Visualization for Resting blood pressure, Serum cholesterol, Maximum heart rate achieved and  Oldpeak (ST)

# %%
numeric_cols=['restingBP','serumcholestrol','maxheartrate','oldpeak']
for i in numeric_cols:
    
    plt.figure(figsize=(20,12))
    plot=sns.relplot(data=df, x='age', y=i, kind='line', hue=df['gender'].map(gender), style='gender',col='gender')
    plot.set_titles("{col_name} Gender")

    # Add a main title
    plt.suptitle(f"{i} vs. Age by Gender", y=1.02)

    plt.show()

# %% [markdown]
# # Visualization for Fasting Blood sugar

# %%
df.fastingbloodsugar.nunique()
# Out:
# 2

# %%
df.fastingbloodsugar.value_counts()
# Out:
# 0    704
# 1    296
# Name: fastingbloodsugar, dtype: int64

# %%
fasting_dict={0:'<120 mg/dl',1:'>120 mg/dl'}
countplot(data=df,column_x='fastingbloodsugar',hue='gender',order=sorted(df['fastingbloodsugar'].unique()),label_dict=fasting_dict)

# %% [markdown]
# # Visualization for Exercise induced angina

# %%
ex_dict={0:'Yes',1:'No'}
df.exerciseangia.nunique()
# Out:
# 2

# %%
countplot(data=df,column_x='exerciseangia',hue='gender',order=sorted(df['exerciseangia'].unique()),label_dict=ex_dict)

# %% [markdown]
# # Visualization for Resting electrocardiogram results

# %%
resting_elctro={0:'Normal',1:'ST-T',2:'LVH'}
countplot(data=df,column_x='restingrelectro',hue='gender',order=sorted(df['restingrelectro'].unique()),label_dict=resting_elctro)

# %% [markdown]
# # Applying Random Forrest Classification to predict Absence or Presence of Heart Disease

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
le=LabelEncoder()
df['gender']=le.fit_transform(df['gender'])
df['gender'].tail()
# Out:
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: gender, dtype: int64

# %%
x=df.iloc[:,1:13]
print(x)
y=df['target']
print(y)
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0     53       1          2        171                0                  0
# 1     40       1          0         94              229                  0
# 2     49       1          2        133              142                  0
# 3     43       1          0        138              295                  1
# 4     31       1          1        199                0                  0
# ..   ...     ...        ...        ...              ...                ...
# 995   48       1          2        139              349                  0
# 996   47       1          3        143              258                  1
# 997   69       1          0        156              434                  1
# 998   45       1          1        186              417                  0
# 999   25       1          0        158              270                  0
#
#      restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0                  1           147              0      5.3      3
# 1                  1           115              0      3.7      1
# 2                  0           202              1      5.0      1
# 3                  1           153              0      3.2      2
# 4                  2           136              0      5.3      3
# ..               ...           ...            ...      ...    ...
# 995                2           183              1      5.6      2
# 996                1            98              1      5.7      1
# 997                0           196              0      1.4      3
# 998                1           117              1      5.9      3
# 999                0           143              1      4.7      0
#
#      noofmajorvessels
# 0                   3
# 1                   1
# 2                   0
# 3                   2
# 4                   2
# ..                ...
# 995                 2
# 996                 0
# 997                 1
# 998                 2
# 999                 0
#
# [1000 rows x 12 columns]
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    0
# Name: target, Length: 1000, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)
model = RandomForestClassifier(n_estimators=100,criterion='entropy') # the number of decision trees 
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
model.score(x_train, y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.98

# %%
y_predicted = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[ 78,   3],
#        [  1, 118]], dtype=int64)

# %%
plt.figure(figsize=(14,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(105.0, 0.5, 'Truth')

# %%
print(classification_report(y_test, y_predicted))
print(accuracy_score(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        81
#            1       0.98      0.99      0.98       119
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.98      0.98      0.98       200
#
# 0.98
